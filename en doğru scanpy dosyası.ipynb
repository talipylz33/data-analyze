# %%
pip install plotnine[all]
# Out:
# ...
#   Obtaining dependency information for numpy>=1.23.0 from https://files.pythonhosted.org/packages/3f/6b/5610004206cf7f8e7ad91c5a85a8c71b2f2f8051a0c0c4d5916b76d6cbb2/numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata
#   Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
# ...
# Using cached numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Erişim engellendi: 'C:\\Users\\volka\\anaconda3\\Lib\\site-packages\\numpy\\~0ibs\\libopenblas64__v0.3.21-gcc_10_3_0.dll'
# Consider using the `--user` option or check the permissions.

# %%
pip install -U scFates
# Out:
# ...
#   Obtaining dependency information for numpy>=1.18.1 from https://files.pythonhosted.org/packages/d8/ec/ebef2f7d7c28503f958f0f8b992e7ce606fb74f9e891199329d5f5f87404/numpy-1.24.4-cp311-cp311-win_amd64.whl.metadata
#   Using cached numpy-1.24.4-cp311-cp311-win_amd64.whl.metadata (5.6 kB)
# ...
# Using cached numpy-1.24.4-cp311-cp311-win_amd64.whl (14.8 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gensim 4.3.0 requires FuzzyTM>=0.4.0, which is not installed.
# tables 3.8.0 requires blosc2~=2.0.0, which is not installed.
# tables 3.8.0 requires cython>=0.29.21, which is not installed.
# ...

# %%
pip install anndata2ri
# Out:
# ...
#
#   Obtaining dependency information for anndata2ri from https://files.pythonhosted.org/packages/d5/d5/cf4e2362f106653fa67866f365796d50457e9a61e087887a06fa49dfea7a/anndata2ri-1.3.1-py3-none-any.whl.metadata
#   Using cached anndata2ri-1.3.1-py3-none-any.whl.metadata (4.9 kB)
# ...
#   Using cached rpy2-3.5.15.tar.gz (219 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [8 lines of output]
#   Unable to determine R home.
#   Unable to determine R home: [WinError 2] Sistem belirtilen dosyayı bulamıyor
#   cffi mode is CFFI_MODE.ANY
#   Looking for R home with: R RHOME
#   Unable to determine R home.
#   Unable to determine R home: [WinError 2] Sistem belirtilen dosyayı bulamıyor
# ...

# %%
pip install rpy2
# Out:
# ...
#   Using cached rpy2-3.5.15.tar.gz (219 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
# Note: you may need to restart the kernel to use updated packages.
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [8 lines of output]
#   Unable to determine R home.
#   Unable to determine R home: [WinError 2] Sistem belirtilen dosyayı bulamıyor
#   cffi mode is CFFI_MODE.ANY
#   Looking for R home with: R RHOME
#   Unable to determine R home.
#   Unable to determine R home: [WinError 2] Sistem belirtilen dosyayı bulamıyor
#   R home found: None
#   Error: rpy2 in API mode cannot be built without R in the PATH or R_HOME defined. Correct this or force ABI mode-only by defining the environment variable RPY2_CFFI_MODE=ABI
# ...

# %%
pip install gprofiler
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import plotnine as pn
import anndata as ad
import scanpy as sc
import scFates as scf

# %%
sc.settings.verbosity = 3             # verbosity: errors (0), warnings (1), info (2), hints (3)
sc.logging.print_header()
sc.settings.set_figure_params(dpi=80, facecolor='white')
# Out:
# scanpy==1.9.8 anndata==0.10.5.post1 umap==0.5.5 numpy==1.24.4 scipy==1.11.1 pandas==1.5.3 scikit-learn==1.3.0 statsmodels==0.14.0 igraph==0.11.3 pynndescent==0.5.11

# %%
import os

dosya_yolu = 'write/1pbmc3k.h5ad'

# Dosyayı 'write' klasöründe '1pbmc3k.h5ad' adıyla oluştur
with open(dosya_yolu, 'wb') as dosya:  # 'wb' modunu kullanın
    pass  # Dosya boş olarak oluşturuldu

# Dosyayı bir değişkene atayın
with open(dosya_yolu, 'rb') as dosya:  # 'rb' modunu kullanın
    results_file = dosya.read()

# İçeriği kontrol etmek için yazdırın
print(results_file)
# Out:
# b''

# %%
adata = sc.read_10x_h5('/users/volka/Scanpython/matrix/A1matrix1.h5', gex_only = False)
# Out:
# reading /users/volka/Scanpython/matrix/A1matrix1.h5
#  (0:00:00)
# C:\Users\volka\anaconda3\Lib\site-packages\anndata\_core\anndata.py:1908: UserWarning: Variable names are not unique. To make them unique, call `.var_names_make_unique`.

# %%
adata.var_names_make_unique()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6268 × 33538
#     var: 'gene_ids', 'feature_types', 'genome'

# %%
adata.X
# Out:
# <6268x33538 sparse matrix of type '<class 'numpy.float32'>'
# 	with 7428071 stored elements in Compressed Sparse Row format>

# %%
sc.pl.highest_expr_genes(adata, n_top = 15)
# Out:
# normalizing counts per cell
#     finished (0:00:00)

# %%
sc.pp.filter_cells(adata, min_genes= 200)
sc.pp.filter_genes(adata, min_cells= 3)
# Out:
# filtered out 254 cells that have less than 200 genes expressed
# filtered out 15553 genes that are detected in less than 3 cells

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 6014 × 17985
#     obs: 'n_genes'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells'

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')

adata.var
# Out:
#                    gene_ids    feature_types  genome  n_cells     mt
# AL627309.1  ENSG00000238009  Gene Expression  GRCh38        3  False
# AL669831.5  ENSG00000237491  Gene Expression  GRCh38      279  False
# FAM87B      ENSG00000177757  Gene Expression  GRCh38        4  False
# LINC00115   ENSG00000225880  Gene Expression  GRCh38       59  False
# FAM41C      ENSG00000230368  Gene Expression  GRCh38       69  False
# ...                     ...              ...     ...      ...    ...
# AC011043.1  ENSG00000276256  Gene Expression  GRCh38        4  False
# AL592183.1  ENSG00000273748  Gene Expression  GRCh38      130  False
# AC007325.4  ENSG00000278817  Gene Expression  GRCh38       72  False
# AL354822.1  ENSG00000278384  Gene Expression  GRCh38       17  False
# AC240274.1  ENSG00000271254  Gene Expression  GRCh38        9  False
#
# [17985 rows x 5 columns]

# %%
adata.var['mt'] = adata.var_names.str.startswith('MT-')
sc.pp.calculate_qc_metrics(adata, qc_vars= ['mt'], percent_top = None, log1p = False,
                          inplace = True)

# %%
sc.pp.calculate_qc_metrics(adata, qc_vars=['mt'], percent_top=None, log1p=False, inplace=True)

# %%
sc.pl.violin(adata, ['n_genes_by_counts', 'total_counts', 'pct_counts_mt'],
            jitter = 0.4, multi_panel=True)
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\seaborn\axisgrid.py:123: UserWarning: The figure layout has changed to tight

# %%
adata.var
# Out:
#                    gene_ids    feature_types  genome  n_cells     mt  \
# AL627309.1  ENSG00000238009  Gene Expression  GRCh38        3  False
# AL669831.5  ENSG00000237491  Gene Expression  GRCh38      279  False
# FAM87B      ENSG00000177757  Gene Expression  GRCh38        4  False
# LINC00115   ENSG00000225880  Gene Expression  GRCh38       59  False
# FAM41C      ENSG00000230368  Gene Expression  GRCh38       69  False
# ...                     ...              ...     ...      ...    ...
# AC011043.1  ENSG00000276256  Gene Expression  GRCh38        4  False
# AL592183.1  ENSG00000273748  Gene Expression  GRCh38      130  False
# AC007325.4  ENSG00000278817  Gene Expression  GRCh38       72  False
# AL354822.1  ENSG00000278384  Gene Expression  GRCh38       17  False
# AC240274.1  ENSG00000271254  Gene Expression  GRCh38        9  False
#
#             n_cells_by_counts  mean_counts  pct_dropout_by_counts  \
# AL627309.1                  3     0.000499              99.950116
# ...

# %%
adata.obs
# Out:
#                     n_genes  n_genes_by_counts  total_counts  total_counts_mt  \
# AAACCCAAGATTAGAC-1     1669               1669        4133.0            481.0
# AAACCCAAGGATTTCC-1     1150               1150        3690.0            241.0
# AAACCCAAGTCAACAA-1     1391               1391        6854.0            312.0
# AAACCCAAGTCGGCAA-1     1668               1668        6922.0            456.0
# AAACCCACAAATTAGG-1      754                753        1631.0            272.0
# ...                     ...                ...           ...              ...
# TTTGTTGGTAAGGAGA-1      402                402         825.0            218.0
# TTTGTTGGTCCAGTTA-1     1806               1805        5059.0            268.0
# TTTGTTGTCCCTTTGG-1     1372               1371        3825.0            193.0
# TTTGTTGTCTACAGGT-1     2193               2193        6957.0            472.0
# TTTGTTGTCTATCGCC-1     1679               1677        5734.0            213.0
#
# ...

# %%
p = (
    pn.ggplot(adata.obs,pn.aes(x = 'total_counts'))
    + pn.geom_histogram()
)
p.draw()
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\plotnine\stats\stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 162'. Pick better value with 'binwidth'.

# %%
p = (
    pn.ggplot(adata.obs,pn.aes(x = 'n_genes_by_counts'))
    + pn.geom_histogram()
)
p.draw()
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\plotnine\stats\stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 66'. Pick better value with 'binwidth'.

# %%
adata.obs
# Out:
#                     n_genes  n_genes_by_counts  total_counts  total_counts_mt  \
# AAACCCAAGATTAGAC-1     1669               1669        4133.0            481.0
# AAACCCAAGGATTTCC-1     1150               1150        3690.0            241.0
# AAACCCAAGTCAACAA-1     1391               1391        6854.0            312.0
# AAACCCAAGTCGGCAA-1     1668               1668        6922.0            456.0
# AAACCCACAAATTAGG-1      754                753        1631.0            272.0
# ...                     ...                ...           ...              ...
# TTTGTTGGTAAGGAGA-1      402                402         825.0            218.0
# TTTGTTGGTCCAGTTA-1     1806               1805        5059.0            268.0
# TTTGTTGTCCCTTTGG-1     1372               1371        3825.0            193.0
# TTTGTTGTCTACAGGT-1     2193               2193        6957.0            472.0
# TTTGTTGTCTATCGCC-1     1679               1677        5734.0            213.0
#
# ...

# %%
sc.pl.scatter(adata, x = 'total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x = 'total_counts', y='n_genes_by_counts')

# %%
adata = adata[adata.obs.pct_counts_mt <20, :]
adata = adata[adata.obs.n_genes_by_counts < 500, :]

# %%
sc.pl.scatter(adata, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata, x='total_counts', y='n_genes_by_counts')

# %%
sc.pp.normalize_total(adata, target_sum=1e4)
# Out:
# normalizing counts per cell
#     finished ({time_passed})
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\preprocessing\_normalization.py:169: UserWarning: Received a view of an AnnData. Making a copy.

# %%
sc.pp.log1p(adata)

# %%
sc.pp.highly_variable_genes(adata, min_mean = 0.0125, max_mean =3, min_disp =0.5)
# Out:
# extracting highly variable genes
#     finished (0:00:00)
# --> added
#     'highly_variable', boolean vector (adata.var)
#     'means', float vector (adata.var)
#     'dispersions', float vector (adata.var)
#     'dispersions_norm', float vector (adata.var)

# %%
sc.pl.highly_variable_genes(adata)

# %%
adata.raw = adata

# %%
adata = adata[:, adata.var.highly_variable]

# %%
sc.pp.regress_out(adata,['total_counts', 'pct_counts_mt'])
# Out:
# regressing out ['total_counts', 'pct_counts_mt']
#     sparse input is densified and may lead to high memory use
#     finished (0:00:04)

# %%
sc.pp.scale(adata, max_value=10)

# %%
sc.tl.pca(adata, svd_solver='arpack')
# Out:
# computing PCA
#     on highly variable genes
#     with n_comps=50
#     finished (0:00:00)

# %%
sc.pl.pca(adata, color='ATAD3A')

# %%
sc.pl.pca_variance_ratio(adata, log=True)

# %%
adata.write_h5ad(dosya_yolu)

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 429 × 2477
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'log1p', 'hvg', 'pca'
#     obsm: 'X_pca'
#     varm: 'PCs'

# %%
sc.pp.neighbors(adata, n_neighbors = 10, n_pcs = 40)
# Out:
# computing neighbors
#     using 'X_pca' with n_pcs = 40
#     finished: added to `.uns['neighbors']`
#     `.obsp['distances']`, distances for each pair of neighbors
#     `.obsp['connectivities']`, weighted adjacency matrix (0:00:02)

# %%
adata.uns['neighbors']
# Out:
# {'connectivities_key': 'connectivities',
#  'distances_key': 'distances',
#  'params': {'n_neighbors': 10,
#   'method': 'umap',
#   'random_state': 0,
#   'metric': 'euclidean',
#   'n_pcs': 40}}

# %%
sc.tl.leiden(adata, resolution=0.3)
# Out:
# running Leiden clustering
#     finished: found 3 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.tl.paga(adata)
sc.pl.paga(adata)
# Out:
# running PAGA
#     finished: added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns) (0:00:00)
# --> added 'pos', the PAGA positions (adata.uns['paga'])

# %%
sc.pl.paga(adata, color='leiden')
# Out:
# --> added 'pos', the PAGA positions (adata.uns['paga'])

# %%
sc.tl.paga(adata)
sc.pl.paga(adata, plot=False)  # remove `plot=False` if you want to see the coarse-grained graph
sc.tl.umap(adata, init_pos='paga')
# Out:
# running PAGA
#     finished: added
#     'paga/connectivities', connectivities adjacency (adata.uns)
#     'paga/connectivities_tree', connectivities subtree (adata.uns) (0:00:00)
# --> added 'pos', the PAGA positions (adata.uns['paga'])
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)

# %%
sc.tl.umap(adata)
# Out:
# computing UMAP
#     finished: added
#     'X_umap', UMAP coordinates (adata.obsm) (0:00:01)

# %%
print(adata.obs)
print(adata.var_names)
# Out:
#                     n_genes  n_genes_by_counts  total_counts  total_counts_mt  \
# AAACGAAGTTAGGCCC-1      404                404         577.0             64.0
# AAAGAACCAAGAGCTG-1      437                437         882.0            167.0
# AAAGGTAGTGGCACTC-1      360                360         743.0             42.0
# AACAAAGAGCATGCAG-1      480                480         859.0            140.0
# AACAAGACAGCGCTTG-1      447                446        1039.0            181.0
# ...                     ...                ...           ...              ...
# TTGTTCACATCCGCGA-1      448                448         888.0             91.0
# TTGTTTGAGGAACGCT-1      346                346         721.0            112.0
# TTTGGAGCATCATCCC-1      354                354         803.0            143.0
# TTTGGTTAGGAACGAA-1      430                430         760.0            147.0
# TTTGGTTGTGCCCACA-1      470                469        1101.0            134.0
#
# ...

# %%
sc.pl.umap(adata, color=['ATAD3A', 'FO704657.1', 'SLC35E2B'])

# %%
sc.tl.leiden(adata)
# Out:
# running Leiden clustering
#     finished: found 8 clusters and added
#     'leiden', the cluster labels (adata.obs, categorical) (0:00:00)

# %%
sc.pl.umap(adata, color=['leiden', 'FAM207A', 'COL6A1'])
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored

# %%
adata.write(dosya_yolu)

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='t-test')
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
# Out:
# ranking genes
#     finished: added to `.uns['rank_genes_groups']`
#     'names', sorted np.recarray to be indexed by group ids
#     'scores', sorted np.recarray to be indexed by group ids
#     'logfoldchanges', sorted np.recarray to be indexed by group ids
#     'pvals', sorted np.recarray to be indexed by group ids
#     'pvals_adj', sorted np.recarray to be indexed by group ids (0:00:00)

# %%
sc.settings.verbosity = 2  # reduce the verbosity

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='wilcoxon')
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
# Out:
# ranking genes
#     finished (0:00:00)

# %%
adata.write(dosya_yolu)

# %%
sc.tl.rank_genes_groups(adata, 'leiden', method='logreg')
sc.pl.rank_genes_groups(adata, n_genes=25, sharey=False)
# Out:
# ranking genes
#     finished (0:00:02)
# C:\Users\volka\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression

# %%
marker_genes =['ATAD3A', 'FO704657.1', 'SLC35E2B',
               'AL590822.2', 'SKI', 'PEX10','AL139246.5',
               'WRAP73', 'AL805961.2', 'VAMP3','RSPH1', 
               'CSTB', 'AP001059.2', 'PFKL', 'TRPM2', 
               'ITGB2', 'ITGB2-AS1','FAM207A', 'COL6A1', 'PRMT2']

# %%
adata = sc.read(dosya_yolu)
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.

# %%
pd.DataFrame(adata.uns['rank_genes_groups']['names']).head(5)
# Out:
#           0        1        2      3       4      5       6     7
# 0      CD74   MT-CO3     IGHM  HLA-C  MALAT1  CXCL8   RPL34  HBA1
# 1  HLA-DRB1   MT-CYB    NEIL1   GNLY   SARAF  NAMPT   RPL7A   HBB
# 2   HLA-DRA   MT-CO2   NFKBID   CCL5  PRRC2C  NEAT1   RPS24  HBA2
# 3    MT-ND3   RICTOR    CD79A  HLA-B  SAMHD1  HIF1A   RPS11  AHSP
# 4    MT-CYB  ANKRD12  HLA-DRA    CD7   RPS21  THBS1  TMSB10   HBM

# %%
result = adata.uns['rank_genes_groups']
groups = result['names'].dtype.names
pd.DataFrame(
    {group + '_' + key[:1]: result[key][group]
    for group in groups for key in ['names', 'pvals']}).head(5)
# Out:
#         0_n           0_p      1_n           1_p      2_n           2_p  \
# 0      CD74  2.450977e-17   MT-CO3  1.972231e-07     IGHM  2.193785e-13
# 1  HLA-DRB1  5.209071e-17   MT-CYB  3.630276e-04    NEIL1  1.237054e-07
# 2   HLA-DRA  4.190503e-11   MT-CO2  4.404671e-04   NFKBID  2.039642e-07
# 3    MT-ND3  2.266132e-09   RICTOR  3.540282e-03    CD79A  3.335316e-07
# 4    MT-CYB  2.739031e-09  ANKRD12  3.895158e-03  HLA-DRA  6.215525e-07
#
#      3_n           3_p     4_n           4_p    5_n           5_p     6_n  \
# 0  HLA-C  6.962133e-11  MALAT1  2.586380e-07  CXCL8  8.139620e-10   RPL34
# 1   GNLY  7.059111e-10   SARAF  4.730054e-03  NAMPT  1.023313e-09   RPL7A
# 2   CCL5  4.593625e-09  PRRC2C  5.549715e-03  NEAT1  1.166429e-09   RPS24
# 3  HLA-B  1.680172e-08  SAMHD1  8.751663e-03  HIF1A  2.485226e-07   RPS11
# 4    CD7  5.899348e-08   RPS21  1.561822e-02  THBS1  5.715109e-07  TMSB10
#
#         6_p   7_n           7_p
# 0  0.000004  HBA1  2.815796e-07
# ...

# %%
sc.tl.rank_genes_groups(adata, 'leiden', groups=['0'], reference='1', method='wilcoxon')
sc.pl.rank_genes_groups(adata, groups=['0'], n_genes=20)
# Out:
# ranking genes
#     finished (0:00:00)

# %%
sc.pl.rank_genes_groups_violin(adata, groups='0', n_genes=8)
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_tools\__init__.py:1170: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_tools\__init__.py:1183: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_tools\__init__.py:1199: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
adata = sc.read(dosya_yolu)
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\anndata\__init__.py:51: FutureWarning: `anndata.read` is deprecated, use `anndata.read_h5ad` instead. `ad.read` will be removed in mid 2024.

# %%
sc.pl.rank_genes_groups_violin(adata, groups='0', n_genes=8)
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_tools\__init__.py:1170: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_tools\__init__.py:1183: FutureWarning:
#
# Setting a gradient palette using color= is deprecated and will be removed in v0.14.0. Set `palette='dark:black'` for the same effect.
#
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_tools\__init__.py:1199: UserWarning: FixedFormatter should only be used together with FixedLocator

# %%
sc.pl.violin(adata, ['FAM207A', 'COL6A1', 'PRMT2'], groupby='leiden')
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_anndata.py:839: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_anndata.py:839: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_anndata.py:839: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_anndata.py:839: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
# ...

# %%
new_cluster_names = [
    'T', 'NK',
    'B', 'M',
    'pDC', 'E',
    'SC', 'NB']
adata.rename_categories('leiden', new_cluster_names)

# %%
sc.pl.umap(adata, color='leiden', legend_loc='on data', title='', frameon=False, save='.pdf')
# Out:
# WARNING: saving figure to file figures\umap.pdf
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_tools\scatterplots.py:394: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored

# %%
sc.pl.dotplot(adata, marker_genes, groupby='leiden');
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_dotplot.py:747: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap', 'norm' will be ignored

# %%
sc.pl.rank_genes_groups_matrixplot(adata,n_genes=3,standard_scale='var')

# %%
sc.pl.stacked_violin(adata, marker_genes, groupby='leiden');
# Out:
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_stacked_violin.py:461: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_stacked_violin.py:461: UserWarning: Numpy array is not a supported type for `palette`. Please convert your palette to a list. This will become an error in v0.14
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_stacked_violin.py:461: FutureWarning:
#
# The `scale` parameter has been renamed and will be removed in v0.15.0. Pass `density_norm='width'` for the same effect.
# C:\Users\volka\anaconda3\Lib\site-packages\scanpy\plotting\_stacked_violin.py:461: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 429 × 2477
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'hvg', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'neighbors', 'paga', 'pca', 'rank_genes_groups', 'umap', 'dendrogram_leiden'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.write(dosya_yolu, compression='gzip')  # `compression='gzip'` saves disk space, but slows down writing and subsequent reading

# %%
adata.raw.to_adata().write('./write/pbmc3k_withoutX.h5ad')

# %%
adata.raw.to_adata().write('./write/1pbmc3k_withoutX.h5ad')

# %%
import anndata

# H5AD dosyasını yükleyin
adata_loaded = anndata.read_h5ad('./write/pbmc3k_withoutX.h5ad')

# Verilerin bir özetini görüntüleyin
print(adata_loaded)
# Out:
# AnnData object with n_obs × n_vars = 429 × 17985
#     obs: 'n_genes', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'leiden'
#     var: 'gene_ids', 'feature_types', 'genome', 'n_cells', 'mt', 'n_cells_by_counts', 'mean_counts', 'pct_dropout_by_counts', 'total_counts', 'highly_variable', 'means', 'dispersions', 'dispersions_norm'
#     uns: 'dendrogram_leiden', 'hvg', 'leiden', 'leiden_colors', 'leiden_sizes', 'log1p', 'neighbors', 'paga', 'pca', 'rank_genes_groups', 'umap'
#     obsm: 'X_pca', 'X_umap'
#     obsp: 'connectivities', 'distances'
